# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('Image/AIth.jpg')
plt.imshow(img)
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('Image/AIth.jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import numpy as np

# %%
print(img.shape)
# Out:
# (480, 720, 3)

# %%
z = img.reshape(-1, 3)
print(z.shape)
z = np.float32(z)
# Out:
# (345600, 3)

# %%
critera = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER,10,1.0)

k=7

ret, label, center = cv2.kmeans(z,k,None, critera, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
print(center)
# Out:
# [[165.38548   180.2366    198.20827  ]
#  [191.68466   199.6537    211.29187  ]
#  [206.04277   184.07956   131.48332  ]
#  [235.49896   231.72829   228.64873  ]
#  [210.05428   193.0155    151.09174  ]
#  [225.875     208.75      155.8125   ]
#  [ 65.011444   71.49855    76.531906 ]
#  [190.2722    184.2971    147.91785  ]
#  [239.192     226.8228    192.25192  ]
#  [242.52744   229.84404   200.1091   ]
#  [163.99454   107.62704    55.38495  ]
#  [246.8469    234.07655   208.20193  ]
#  [232.89471   232.70398   213.16426  ]
#  [219.57068   198.98953   148.73299  ]
#  [223.59183   206.12245   158.30612  ]
#  [ 46.91391    47.74347    47.243763 ]
#  [224.93567   210.07602   165.1345   ]
#  [217.66437   199.34256   162.06921  ]
#  [230.88641   227.06032   221.82341  ]
#  [131.47986   119.609116   71.558586 ]
#  [ 46.203125   54.648438  120.10156  ]
#  [202.32684   140.89417    96.49027  ]
#  [ 42.87704    57.423077   69.63083  ]
#  [227.85106   201.97871   163.19148  ]
#  [120.40106   130.83607   138.13492  ]
#  [229.72862   214.97397   171.58365  ]
#  [ 90.59039    98.96003   103.995605 ]
#  [225.40425   221.73657   216.36406  ]
#  [236.50473   183.36568   152.96805  ]
#  [ 33.569702   44.894886   53.006668 ]
#  [ 39.73469    39.724487  221.66325  ]
#  [243.1298    199.44643   173.12775  ]
#  [212.29898   208.80789   176.86769  ]
#  [251.02463   242.56773   224.5      ]
#  [162.4814    154.59363   101.37387  ]
#  [181.50873   170.58565   121.744644 ]
#  [ 16.875      22.9        76.825005 ]
#  [ 28.877253   37.794296   43.58052  ]
#  [ 79.45116    96.66252   137.8508   ]
#  [  4.7166667  12.800001   28.500002 ]
#  [  3.027353    4.0716276   2.574229 ]
#  [197.61583   194.13309   174.87985  ]
#  [240.93219   193.3715    165.51846  ]
#  [ 21.182373   29.01259    34.481876 ]
#  [ 11.021462   15.431036   16.257654 ]
#  [226.89584   216.87868   180.45956  ]
#  [ 44.63653    40.425983   13.773182 ]
#  [230.04617   169.20055   134.18243  ]
#  [ 88.46665    75.00293    39.799686 ]
#  [ 31.280598   34.605236   35.989983 ]
#  [ 32.577347   30.854244    6.1559076]
#  [112.585106  126.87082   188.66565  ]
#  [ 14.254839   19.423178   20.962605 ]
#  [ 24.468683   23.370195    7.176458 ]
#  [217.98465   214.86902   209.4097   ]
#  [245.1328    238.16759   216.4158   ]
#  [ 60.6953     52.780144   22.768131 ]
#  [ 19.669271   21.31037    20.731535 ]
#  [ 15.070292   13.244805    3.8512511]
#  [203.04959   201.48637   193.86826  ]
#  [148.14499   158.14554   165.20105  ]
#  [177.1148    178.52112   175.0466   ]
#  [228.95079   222.57152   189.96529  ]
#  [ 22.570679   26.352386   27.835238 ]
#  [213.85715   215.25217   190.75743  ]
#  [249.97289   245.236     237.66637  ]
#  [ 32.761578   31.625042   17.614408 ]
#  [  6.6094522  10.809062   10.750236 ]
#  [228.2157    226.8866    202.18556  ]
#  [254.42117   253.65955   251.07057  ]]

# %%
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

# %%
plt.imshow(cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(res2, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img = cv2.imread("AIth.jpg")
clustering(img, 2)
clustering(img, 4)
clustering(img, 8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-cea5d3976a5b> in <module>
#       1 img = cv2.imread("AIth.jpg")
# ----> 2 clustering(img, 2)
#       3 clustering(img, 4)
#       4 clustering(img, 8)
#
# NameError: name 'clustering' is not defined
